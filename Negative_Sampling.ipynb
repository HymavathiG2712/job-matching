# %%
import pandas as pd

# %%
df = pd.read_csv('rdataset.csv')

# %%
df
# Out:
#     Category                                             Resume
# 0         HR  TECHNICAL SKILLS â¢ Typewriting â¢ TORA â¢ ...
# 1         HR  I.T. Skills â¢ Windows XP, Ms Office (Word, E...
# 2         HR  Education Details \r\n BA   mumbai University\...
# 3         HR  Education Details \r\nJune 2012 to May 2015 B....
# 4         HR  Education Details \r\nJune 2012 to May 2015 B....
# ..       ...                                                ...
# 917      NaN                                                NaN
# 918      NaN                                                NaN
# 919      NaN                                                NaN
# 920      NaN                                                NaN
# 921      NaN                                                NaN
#
# [922 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Category    588
# Resume      588
# dtype: int64

# %%
df['JD'] = ''

# %%
df2 = pd.read_csv('dice_com-job_us_sample.csv')

# %%
df2
# Out:
#                                            advertiserurl  \
# 0      https://www.dice.com/jobs/detail/AUTOMATION-TE...
# 1      https://www.dice.com/jobs/detail/Information-S...
# 2      https://www.dice.com/jobs/detail/Business-Solu...
# 3      https://www.dice.com/jobs/detail/Java-Develope...
# 4      https://www.dice.com/jobs/detail/DevOps-Engine...
# ...                                                  ...
# 21995  https://www.dice.com/jobs/detail/Web-Designer-...
# 21996  https://www.dice.com/jobs/detail/Senior-Front-...
# 21997  https://www.dice.com/jobs/detail/QA-Analyst-Sa...
# 21998  https://www.dice.com/jobs/detail/Tech-Lead%252...
# 21999  https://www.dice.com/jobs/detail/C%2526%252347...
#
#                                  company  \
# 0      Digital Intelligence Systems, LLC
# 1      University of Chicago/IT Services
# 2                   Galaxy Systems, Inc.
# 3                          TransTech LLC
# 4                       Matrix Resources
# ...

# %%
# select a jobdescription from the second dataframe
for i in range(len(df)):
    jobdesc = df2['jobdescription'][i]

    # fill the JD column of the first dataframe with the selected jobdescription
    df['JD'][i] = jobdesc

# save the updated dataframe to a new csv file
# df.to_csv('updated_first_dataframe.csv', index=False)

# %%
df.dropna()
# Out:
#     Category                                             Resume  \
# 0         HR  TECHNICAL SKILLS â¢ Typewriting â¢ TORA â¢ ...
# 1         HR  I.T. Skills â¢ Windows XP, Ms Office (Word, E...
# 2         HR  Education Details \r\n BA   mumbai University\...
# 3         HR  Education Details \r\nJune 2012 to May 2015 B....
# 4         HR  Education Details \r\nJune 2012 to May 2015 B....
# ..       ...                                                ...
# 664      PMO  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 665      PMO  Skills Exceptional communication and networkin...
# 666      PMO  CORE COMPETENCIES â¢ Maintain processes to en...
# 667      PMO  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 668      PMO  Skills Exceptional communication and networkin...
#
#                                                     JD
# 0    Looking for Selenium engineers...must have sol...
# 1    The University of Chicago has a rapidly growin...
# ...

# %%
df.to_csv('334unrelated.csv')

# %%
r = pd.read_csv('Resume.csv')

# %%
r['Category'].unique()
# Out:
# array(['HR', 'DESIGNER', 'INFORMATION-TECHNOLOGY', 'TEACHER', 'ADVOCATE',
#        'BUSINESS-DEVELOPMENT', 'HEALTHCARE', 'FITNESS', 'AGRICULTURE',
#        'BPO', 'SALES', 'CONSULTANT', 'DIGITAL-MEDIA', 'AUTOMOBILE',
#        'CHEF', 'FINANCE', 'APPAREL', 'ENGINEERING', 'ACCOUNTANT',
#        'CONSTRUCTION', 'PUBLIC-RELATIONS', 'BANKING', 'ARTS', 'AVIATION'],
#       dtype=object)

# %%
r = r[~r['Category'].isin(['INFORMATION-TECHNOLOGY', 'ENGINEERING','CONSULTANT', 'DIGITAL-MEDIA'])]

# %%
r['Resume_Text'] = r['Resume_str']
# Out:
# /tmp/ipykernel_644777/3734615021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r['Resume_Text'] = r['Resume_str']

# %%
r.drop(['Resume_str', 'ID', 'Resume_html','Category'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_644777/1328273305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r.drop(['Resume_str', 'ID', 'Resume_html','Category'], axis=1, inplace=True)

# %%
r
# Out:
#                                                      JD  \
# 0     Position:   Oracle Financial Specialist Locati...
# 1     Are you passionate about delivering goals to y...
# 2     Who we are: Incapsulate provides services from...
# 3     Our client northwest of Boston is in need of a...
# 4     Full time HireThe Sales Manager is responsible...
# ...                                                 ...
# 2479
# 2480
# 2481
# 2482
# 2483
#
#                                             Resume_Text
# 0              HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1              HR SPECIALIST, US HR OPERATIONS      ...
# 2              HR DIRECTOR       Summary      Over 2...
# 3              HR SPECIALIST       Summary    Dedica...
# 4              HR MANAGER         Skill Highlights  ...
# ...                                                 ...
# 2479           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...
# 2480           GOVERNMENT RELATIONS, COMMUNICATIONS ...
# ...

# %%
df3 = df2[1000:]

# %%
r.reset_index(inplace=True)
df3
# Out:
#       level_0  index                                      advertiserurl  \
# 0           0   1000  https://www.dice.com/jobs/detail/Oracle-Financ...
# 1           1   1001  https://www.dice.com/jobs/detail/Strategy-Cons...
# 2           2   1002  https://www.dice.com/jobs/detail/Sr.-Project-M...
# 3           3   1003  https://www.dice.com/jobs/detail/Network-Engin...
# 4           4   1004  https://www.dice.com/jobs/detail/Sales-Represe...
# ...       ...    ...                                                ...
# 2536     2536  18353  https://www.dice.com/jobs/detail/Senior-C%252B...
# 2537     2537  18355  https://www.dice.com/jobs/detail/Software-Deve...
# 2538     2538  18357  https://www.dice.com/jobs/detail/Storage-Admin...
# 2539     2539  18358  https://www.dice.com/jobs/detail/Lead-Data-Int...
# 2540     2540  18359  https://www.dice.com/jobs/detail/ACD-%2528Desi...
#
#                      company  \
# 0        Beacon Systems, Inc
# 1                   Deloitte
# ...

# %%
# select a jobdescription from the second dataframe
for i in range(len(r)):
    jobdesc = df3['jobdescription'][i]

    # fill the JD column of the first dataframe with the selected jobdescription
    r['JD'][i] = jobdesc
# Out:
# /tmp/ipykernel_644777/3269456096.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r['JD'][i] = jobdesc

# %%
r
# Out:
#       index                                                 JD  \
# 0         0  Position:   Oracle Financial Specialist Locati...
# 1         1  Are you passionate about delivering goals to y...
# 2         2  Who we are: Incapsulate provides services from...
# 3         3  Our client northwest of Boston is in need of a...
# 4         4  Full time HireThe Sales Manager is responsible...
# ...     ...                                                ...
# 2030   2479  Windows Development EngineerDenver, CO (prefer...
# 2031   2480  Title: Senior Software EngineerLocation: Chica...
# 2032   2481  Operations Center AdminTaos is a 26 year old B...
# 2033   2482  If Candidate is on H1B or OPT he has to work o...
# 2034   2483  As a Sales Data Insights Manager, you will dev...
#
#                                             Resume_Text
# 0              HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1              HR SPECIALIST, US HR OPERATIONS      ...
# ...

# %%
r.isnull().sum()
# Out:
# JD             0
# Resume_Text    0
# dtype: int64

# %%
df3.dropna(inplace=True)
# Out:
# /tmp/ipykernel_644777/1665326329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.dropna(inplace=True)

# %%
df3.isnull().sum()
# Out:
# advertiserurl               0
# company                     0
# employmenttype_jobstatus    0
# jobdescription              0
# jobid                       0
# joblocation_address         0
# jobtitle                    0
# postdate                    0
# shift                       0
# site_name                   0
# skills                      0
# uniq_id                     0
# dtype: int64

# %%
r.to_csv('2035unrelated.csv')
