# %%
#Code to convert Text Files to CSV

# %%
import os
import pandas as pd

#Resume Corpus Path here
folder_path = ''

designation = []
for file_name in os.listdir(folder_path):
    if file_name.endswith('.lab'):
        file_path = os.path.join(folder_path, file_name)
        with open(file_path, 'r') as file:
            file_contents = file.read()
            designation.append(file_contents)

resume_description = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        file_path = os.path.join(folder_path, file_name)
        with open(file_path, 'r',encoding='ISO-8859-1') as file:
            file_contents = file.read()
            resume_description.append(file_contents)

df = pd.DataFrame({'Job_Designation': designation, 'Resume_Description': resume_description})
df
# Out:
#                                     Job_Designation  \
# 0                            Database_Administrator
# 1        Database_Administrator\nSoftware_Developer
# 2                            Database_Administrator
# 3                            Database_Administrator
# 4     Database_Administrator\nSystems_Administrator
# ...                                             ...
# 4995                         Database_Administrator
# 4996                         Database_Administrator
# 4997                         Database_Administrator
# 4998                                Project_manager
# 4999                         Database_Administrator
#
#                                      Resume_Description
# 0     Principal Consultant Principal Consultant Prin...
# 1     Application/UI Developer Application/UI <span ...
# 2     Front End UX Web Accessibility Developer <span...
# 3     ORACLE DATABASE ADMINISTRATOR ORACLE <span cla...
# ...

# %%
#df.to_csv
df.to_csv("job_resumes.csv")
